# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

file_name="/content/analysis_origin.xlsx"
sheet="migrant_world"
df=pd.read_excel(io=file_name,sheet_name=sheet,index_col="Year")
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 8))
ax=df.plot(color=colors,grid=True,title="Trendline of countries with maximum outflow \n wrt world migrants(both sexes)")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total world migrants")
fig=ax.get_figure()
fig.savefig("totalworldmig.png")

# %%
sheet="male_world"
df=pd.read_excel(io=file_name,sheet_name=sheet,index_col="Year")
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 8))
ax=df.plot(color=colors,grid=True,title="Trendline of countries with maximum outflow \n wrt world migrants(male)")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total world migrants")
fig=ax.get_figure()
fig.savefig("totalworldmig_male.png")

# %%
sheet="female_world"
df=pd.read_excel(io=file_name,sheet_name=sheet,index_col="Year")
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 9))
ax=df.plot(color=colors,grid=True,title="Trendline of countries with maximum outflow \n wrt world migrants(female)")
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total world migrants")
fig=ax.get_figure()
fig.savefig("totalworldmig_female.png")

# %%
sheet="male_migrants"
df=pd.read_excel(io=file_name,sheet_name=sheet,index_col="Year")
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 9))
ax=df.plot(color=colors,grid=True,title="Trendline of countries with maximum outflow \n wrt country-wise migrants(male)")
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total migrants of that country")
fig=ax.get_figure()
fig.savefig("totalmig_male.png")

# %%
sheet="female_migrants"
df=pd.read_excel(io=file_name,sheet_name=sheet,index_col="Year")
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 7))
ax=df.plot(color=colors,grid=True,title="Trendline of countries with maximum outflow \n wrt country-wise migrants(female)")
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total migrants of that country")
fig=ax.get_figure()
fig.savefig("totalmig_female.png")

# %%
sheet="percent_pop"
df=pd.read_excel(io=file_name,sheet_name=sheet,index_col="Year")
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 6))
ax=df.plot(color=colors,grid=True,title="Trendline of countries with maximum outflow \n wrt country-wise population(both sexes)")
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total population of that country")
fig=ax.get_figure()
fig.savefig("percent_pop.png")

# %%
sheet="malepop"
df=pd.read_excel(io=file_name,sheet_name=sheet,index_col="Year")
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 7))
ax=df.plot(color=colors,grid=True,title="Trendline of countries with maximum outflow \n wrt country-wise male population")
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total population of that country")
fig=ax.get_figure()
fig.savefig("malepop.png")

# %%
sheet="femalepop"
df=pd.read_excel(io=file_name,sheet_name=sheet,index_col="Year")
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 7))
ax=df.plot(color=colors,grid=True,title="Trendline of countries with maximum outflow \n wrt country-wise female population")
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total population of that country")
fig=ax.get_figure()
fig.savefig("femalepop.png")

# %%
#Bangladesh
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

file_name="bangladesh.xlsx"
df=pd.read_excel(io=file_name,index_col="Year")
#colors = plt.cm.nipy_spectral(np.linspace(0, 1, 13))
ax=df.plot(grid=True,title="Comparison of male and female migrants \nas a percentage of total migrants from Bangladesh")
#ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Migrant stocks as % of total world migrants")
ax.set_xlabel("Year")
fig=ax.get_figure()
fig.savefig("bangladesh.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-7e978f432ce3> in <cell line: 9>()
#       7
#       8 file_name="bangladesh.xlsx"
# ----> 9 df=pd.read_excel(io=file_name,index_col="Year")
#      10 #colors = plt.cm.nipy_spectral(np.linspace(0, 1, 13))
#      11 ax=df.plot(grid=True,title="Comparison of male and female migrants \nas a percentage of total migrants from Bangladesh")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# ...
