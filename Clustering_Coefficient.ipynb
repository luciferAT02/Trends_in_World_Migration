# %%
import matplotlib.pyplot as plt #import library to plot graph

# %%
year=[1990,1995,2000,2005,2010,2015,2020]

# %%
clustering_coefficient=[0.764375856756575,0.7391178374684501,0.7795203621146711,0.8209242327470967,0.7787182777084375,0.7796367086747305,0.8209242327470967]

# %%
plt.plot (year,clustering_coefficients)
plt.title("clustering coefficients for different years")
plt.xlabel("year")
plt.ylabel("clustering coefficient")
plt.show()
